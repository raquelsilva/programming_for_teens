# %% [markdown]
# # First steps in Python

# %% [markdown]
# Let's first learn how to create a new file. At the superior toolbar you find the option "File". Click on it and you will see these other options:

# %%
from IPython.display import Image
Image("images/new_file.jpg")

# %% [markdown]
# Select "New Notebook" and then "Python 2" (or 3).

# %% [markdown]
# You can also download the notebooks I have already created accessing the Githhub repository of the project "programming_for_teens" or at the website you find at the header the link to download the files. See the image below:

# %%
Image("images/download.jpg")

# %% [markdown]
# The notebooks will be downloaded with all the answers already calculated. If you want to see again how it works you need to restart the Kernel. See at the wiki how to do this by clicking on this <a href="https://github.com/raquelsilva/programming_for_teens/wiki/First-step">link</a>.

# %% [markdown]
# To see the result of the code boxes you can compile them one by one by clicking at the play/pause button at the toolbar above. See at the image below the red square and find the play/pause button.

# %%
Image("images/play.jpg")

# %% [markdown]
# To write texts as this you need to click at the selection box where you read now "code" and choose "markdown". To compile this line you click at the play/pause symbol at the toolbar or you can press shift+enter keys. Find the red square in the image bellow and see where it is.

# %%
Image("images/markdown.jpg")

# %% [markdown]
# If you need to print something related to your code you select "code" at the selection box and type: print + something. I will give some examples. But this is not always needed because this compiler gives you the result just below the operation.

# %%
1+1
# Out:
# 2

# %% [markdown]
# But if you need to create a parameter (or argument) consequently you will need to use the command "print".

# %%
sum = 1+1

# %% [markdown]
# In this case, note that the result is not shown below the command. But if you use "print" it will work.

# %%
print sum
# Out:
# 2

# %% [markdown]
# If you want to specify the source of this number, you can add a text before the parameter using quotation marks.

# %%
print '1+1=', sum
# Out:
# 1+1= 2

# %% [markdown]
# The red color at the code below shows that this text between quotation marks is considered as strings (str). Check below:

# %%
type('1+1=')
# Out:
# str

# %% [markdown]
# To create more compicated mathematical operations we usually create functions, which are stored generally in a different file, but you can also create them inside of your working notebook.

# %%
def my_sum():
    sum = 1+1
    print '1+1=', sum

# %% [markdown]
# To verify the result of your function you simply need to digit the name of the function and parenthesis.

# %%
my_sum()
# Out:
# 1+1= 2

# %% [markdown]
# The parenthesis are gateways to input data inside of your function. We will learn it in the next lessons.
